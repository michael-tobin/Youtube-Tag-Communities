# %%
import pandas as pd
import itertools
import os
from io import StringIO
from csv import writer 
import regex as re

# %%
# Load the base data
raw_df = pd.read_pickle('Data_Out/auto_channels_data.pkl')

# %%
# Get some summary stats and a set of all nodes that we can refer to
# word_frequency_dict is for later use in making graphs
unique_words_set = set()
word_frequency_dict = {}

for row in raw_df.VIDEO_TAGS:
    for word in row:
        unique_words_set.add(word)
        word_frequency_dict[word] = word_frequency_dict.get(word, 0) + 1
del word_frequency_dict['']
unique_words_set.remove('')

print('unique_words_set: ',len(unique_words_set))
print('word_frequency_dict: ',len(word_frequency_dict))
# Out:
# unique_words_set:  125708
# word_frequency_dict:  125708

# %%
reg1 = re.compile('[\n]')
nodes = {}
Counter=1
for word in unique_words_set:
    word = re.sub(reg1, '', word)     
    nodes.update({word:Counter})
    Counter+=1
nodes
# Out:
# {'jeepspeed3700': 1,
#  'idiot move': 2,
#  'maybach 2021 v12': 3,
#  '富士急ハイランド': 4,
#  'tata nexon car review': 5,
#  'オムニボット': 6,
#  'noisy brakes': 7,
#  'ram limited': 8,
#  'Tulip Mania (Event)': 9,
#  'Ford Focus RS RX': 10,
#  'ford focus st': 11,
#  'josh kalis': 12,
#  'porschecayenne': 13,
#  'who makes the best luxury car': 14,
#  'rocky mountain race week 2017': 15,
#  'نيسان اكستريل 2018': 16,
#  'H Greg': 17,
#  'camber alignment': 18,
#  'car cleaning tips': 19,
#  'Kia Seltos Rear Space check': 20,
#  'video_de_caminhao': 21,
#  'cutters': 22,
#  'kona': 23,
#  'شيفروليه كمارو': 24,
#  'yezdi scrambler review': 25,
#  'заводится': 26,
#  'fazilat': 27,
#  'koenigsegg agera rs1': 28,
#  'crazy guy vs biker': 29,
#  'ирпень': 30,
#  '2er Coupé': 31,
#  'store closing': 32,
#  'atees': 33,
#  'the Hoonigans': 34,
#  'electric harley': 35,
#  'supra': 36,
#  'car craft week to wicked': 37,
#  'Honda mô tô': 38,
#  'fiat 500 abarth': 39,
#  'corolla EVAP': 40,
#  'Rio Haryanto': 41,
#  'пины': 42,
#  'fwd burnout': 43,
#  'JR Garage': 44,
#  'brake calipers stuck': 45,
#  'best_new_hatchback_2020': 46,
#  'моменты снятые на камеру': 47,
#  'перетягивание каната машинами': 48,
#  'collection video 1': 49,
#  'up to speed ford ranger': 50,
#  'vq': 51,
#  'Fiik Skateboards': 52,
#  'supercar blondie the hulk': 53,
#  'medali emas': 54,
#  'retirement pacman': 55,
#  'PT Aneka Dharma Persada ADP': 56,
#  'tridents': 57,
#  'audi sq5 tdi specs': 58,
#  'ural': 59,
#  'bmw 128ti sound': 60,
#  'zentorno': 61,
#  'розыгрыш': 62,
#  'matsusaka': 63,
#  'несан': 64,
#  'Jeep Grand Cherokee': 65,
#  'shorted car': 66,
#  'roger holden': 67,
#  'maruti baleno new look': 68,
#  'scorpio vs kia race': 69,
#  'Forest': 70,
#  'mondi lamborghini': 71,
#  'laferrari aperta girl': 72,
#  'Ford Ecosport Platinum Edition': 73,
#  'Racing Veyron Chiron': 74,
#  'natrax high speed test track': 75,
#  'test drive of nexon': 76,
#  'nissan x-trail 2021': 77,
#  'Mahindra XUV7OO review': 78,
#  'Headgasket Sealer': 79,
#  'electric_bmw_m': 80,
#  'g37': 81,
#  'Tuatara': 82,
#  'pista review': 83,
#  'Stock Car': 84,
#  'dt 2600 h': 85,
#  'civik': 86,
#  'target fixation': 87,
#  'Tata Tigor EV': 88,
#  'drag race - kia seltos vs scross diesel': 89,
#  'grip hamid sucht luxus klassiker': 90,
#  'melbourne': 91,
#  'оставил на скорости': 92,
#  'scorpio into rolls royce': 93,
#  'ghost': 94,
#  'tutorial_caminho_minecraft': 95,
#  'منافسات فورد اكسبلورر 2020': 96,
#  'поцарапал': 97,
#  'Vorderrad': 98,
#  'how to replace cam sensor 2nd gen dodge ram': 99,
#  'cut down trees': 100,
#  'оползни': 101,
#  'porsche 930': 102,
#  'k24': 103,
#  'ctr': 104,
#  'افخم سيارات 2020': 105,
#  'cold engine ticking': 106,
#  'kbj ep 57': 107,
#  'гризли': 108,
#  'Linde H40D': 109,
#  'living in a trailer': 110,
#  'porsche 911 gt3rs': 111,
#  'Tucker Club': 112,
#  'Sema show': 113,
#  'jdm cars leaving car show': 114,
#  'Audi A1 (Automobile Model)': 115,
#  'car android stereo': 116,
#  'maharashtra chhipakali news': 117,
#  'ford car review': 118,
#  'run': 119,
#  'Compost': 120,
#  'wolkswagen id3': 121,
#  'redneck fun': 122,
#  'Kraftstoff': 123,
#  'сплошная': 124,
#  'hotwheelslabsunlimited': 125,
#  'new kia soul': 126,
#  'wolf im schafspelz teil 9': 127,
#  'm20b25': 128,
#  'tanker truck': 129,
#  'Hägerstraße': 130,
#  'fast station wagon': 131,
#  'lies': 132,
#  'loading Friends': 133,
#  '富士山ビュー特急': 134,
#  'HD270': 135,
#  'đánh giá xe Mitsubishi Outlander 2020': 136,
#  'Stradman House': 137,
#  'rs5_sportback': 138,
#  'cảm biến cáp suất lốp i3': 139,
#  'high jumps': 140,
#  'transmission leaks': 141,
#  'viatura_policia': 142,
#  'motorcycle riders nightmare': 143,
#  'custom paint': 144,
#  'Meerweg': 145,
#  'Muffler': 146,
#  'max verstappen tag heuer': 147,
#  'rr_sport_svr': 148,
#  'amazing_facts_about_thialand': 149,
#  'unreliable used suvs': 150,
#  'road rage karma': 151,
#  'hyundai 2021': 152,
#  'giá xe vinfast vf e34': 153,
#  'supercar blondie fastest car': 154,
#  'fortuner vs xuv mud offroading': 155,
#  'avanza veloz': 156,
#  'EF hatch': 157,
#  'forever stamp': 158,
#  'Х5': 159,
#  'РОССИЙСКИЙ АВТОПРОМ': 160,
#  'AGCO (Business Operation)': 161,
#  'tata altroz launch': 162,
#  'AMG GT R': 163,
#  'top 12': 164,
#  'amg gt s': 165,
#  'Corner Rascal': 166,
#  'Camaro drag car': 167,
#  'swaraj 744 fe 4 star': 168,
#  'اسعار دودج تشالنجر هيلكات': 169,
#  'Alfred Hitchcock': 170,
#  'komunitas rush': 171,
#  'TOYOTA AVANZA': 172,
#  'rolles royce': 173,
#  'mg zs ev 2022 new drive review': 174,
#  'high speed chase': 175,
#  'Ford Ranger Wildtrak': 176,
#  'new creta 2020 mileage': 177,
#  'dzire 2021 petrol': 178,
#  'detail': 179,
#  'Carbon fibre': 180,
#  'профессионал': 181,
#  'xkss': 182,
#  'funny_moments': 183,
#  'how to have fun in 2022': 184,
#  '10 cars': 185,
#  'British motorcycle': 186,
#  'volkswagen touareg 2019 price': 187,
#  'Duo-drive': 188,
#  'films': 189,
#  'Last Day': 190,
#  'Suzuki XL7': 191,
#  'ford has stopped making trucks in america': 192,
#  'surah yaseen with urdu translation full': 193,
#  'twin overhead cam': 194,
#  'skoda octavia rs 245 india': 195,
#  'twin turbo lambo': 196,
#  'apollo 11': 197,
#  'fs_15_mods': 198,
#  '1000 Miglia': 199,
#  'ID.3': 200,
#  'are hondas good cars': 201,
#  'missouri': 202,
#  'bosch': 203,
#  'new_porsche_gt4': 204,
#  'замена колодок': 205,
#  'airstream': 206,
#  '2019 audi rs q8': 207,
#  'lesagri51': 208,
#  'فورد في السعودية': 209,
#  'most_expensive_audi_saloon': 210,
#  'bentley_continental_gt_convertible_review': 211,
#  'bracket racing': 212,
#  'carwow_rs': 213,
#  'tata nexon ev xz plus': 214,
#  'volvo_suv': 215,
#  'من جدة الى الطائف': 216,
#  'highness cb350': 217,
#  '東京ディズニーランド': 218,
#  'Cafe Scrambler': 219,
#  'car ac repair': 220,
#  'mat_watson_tesla': 221,
#  'giá xe suv': 222,
#  '2021 tata safari 7 seater': 223,
#  'Titan': 224,
#  'waxing': 225,
#  'tweedejaars': 226,
#  'PT. PP Presisi': 227,
#  '盛岡': 228,
#  'lfa_2023': 229,
#  '6 series gt': 230,
#  'Banned Auto Group': 231,
#  'kishan': 232,
#  'rvm': 233,
#  'секрет успеха': 234,
#  'Random Excavator Activity | Excavator-saw Modify | Machinery Trucks': 235,
#  'boxster 2020': 236,
#  'TV cars': 237,
#  'b14': 238,
#  'polo review': 239,
#  'Gymkhana 6': 240,
#  'nissan versa': 241,
#  '8 series m850i xdrive': 242,
#  '100k subs': 243,
#  'polestar two review': 244,
#  'سيارة مرسيدس': 245,
#  'f-series': 246,
#  'jay leno vintage cars': 247,
#  'dodge challenger srt-8': 248,
#  'dzire ownership experience': 249,
#  'ссср': 250,
#  'land rover discovery sport facelift 2020': 251,
#  'creta 2021 base model': 252,
#  'поспорим': 253,
#  'chevrolet blazer': 254,
#  '5.3 swap': 255,
#  'toyota corollas': 256,
#  'PS4': 257,
#  '2019 dodge challenger': 258,
#  'давидыч камри': 259,
#  'royal Enfield Meteor 350': 260,
#  'grand i10 nios magna': 261,
#  'magnetic_drift_challenge': 262,
#  'Mystichrome paint': 263,
#  'kbj ep 87': 264,
#  'e car': 265,
#  '#โตโยต้า': 266,
#  'mr 2': 267,
#  "Pure Turbo's": 268,
#  'это видео удалось снять на камеру': 269,
#  'bpcl u fill': 270,
#  'volkswagen xl-1': 271,
#  'not blowing cold air': 272,
#  'top fuel car': 273,
#  'kia carnival india 2022 new model': 274,
#  'Ciaz': 275,
#  'q50 rs400': 276,
#  'Santpoort Zuid': 277,
#  'люди 80 lvl': 278,
#  'nên mua SUV 7 chỗ nào': 279,
#  'hub and wheel bearing replacement': 280,
#  'Million': 281,
#  'Hybris Sports Car': 282,
#  'volkwagen buggy': 283,
#  'Twin Turbo GT3 RS': 284,
#  'senayan': 285,
#  'tractor vs JCB': 286,
#  'блекву': 287,
#  'Rebuilding': 288,
#  'bmw 6 series gt price in india': 289,
#  'xuv300 pros and cons': 290,
#  'максимальное количество людей в маршрутку': 291,
#  'great trucks of 2021': 292,
#  'Amazing work with Mega Machinery & Human Work': 293,
#  'Maschio': 294,
#  'jachts': 295,
#  'hùng lâm đánh giá xe mercedes benz': 296,
#  'ford mustang mach-e gt': 297,
#  'you want the truth heres the truth': 298,
#  'Isuzu Ascender (Automobile Model)': 299,
#  'best paint protection': 300,
#  'siêu xe maserati': 301,
#  'filme_carros': 302,
#  'Rev': 303,
#  'Excavator menghancurkan gedung': 304,
#  'creta sx sunroof': 305,
#  'Figo ad': 306,
#  'lexion': 307,
#  'bigfoot': 308,
#  '金龍': 309,
#  'corvet': 310,
#  'new_vw_tiguan_review': 311,
#  'new tvs apache 165 rp': 312,
#  'Innova Crysta 2020 base model': 313,
#  'dubai festival city cars': 314,
#  'Speed Vegas': 315,
#  '409.1': 316,
#  'bmw m3 g80 sound': 317,
#  'приколы в хоккее': 318,
#  'I HIT MY WIFE with a SOLID AXLE MONSTER TRUCK': 319,
#  'subaru build': 320,
#  'v35': 321,
#  'Cody Walker': 322,
#  'mg hector 2021 new model': 323,
#  'солярис 2': 324,
#  'new_ferrari': 325,
#  'lyle vs rookie': 326,
#  '1933': 327,
#  'почта россии': 328,
#  'kia seltos after sales service': 329,
#  'S65 AMG': 330,
#  '4th Gen 2010-16 W212': 331,
#  'dafnanay': 332,
#  'Vinny S14': 333,
#  'mc dreamy': 334,
#  'make car more modern': 335,
#  'nissan z cars': 336,
#  'texas_killr_r35': 337,
#  'kendaraan ugal-ugalan': 338,
#  'how to gap platinum spark plugs': 339,
#  '2021 MG Hector breakdown': 340,
#  'Máy': 341,
#  '579 semi': 342,
#  'g30': 343,
#  'Личный Видеоблог': 344,
#  'toyota avalon 2020 review': 345,
#  'Ford Ecosport': 346,
#  'jaguar xe project 8': 347,
#  'bmw 760li': 348,
#  'offroading_suv': 349,
#  '950hp': 350,
#  'Keen Project': 351,
#  'Hub Dyno': 352,
#  'турер в': 353,
#  'baru': 354,
#  'lkw': 355,
#  'range rover evoque india': 356,
#  "here's why I went to prison": 357,
#  'блоуоф': 358,
#  'how to use spare tire jack': 359,
#  'porsche boxster 2022': 360,
#  'jaguar xe price': 361,
#  'how to make car last long': 362,
#  'ミニ運転列車': 363,
#  'Sea Saw': 364,
#  'Volvo s90': 365,
#  'islamic amal': 366,
#  'mo vlogs': 367,
#  'сороковой': 368,
#  'Larry Chen Channel': 369,
#  'obstacle': 370,
#  'maruti suzuki electric car': 371,
#  'renault f1': 372,
#  'tire': 373,
#  '1gzg': 374,
#  'wölfe im schafspelz 1': 375,
#  'trucking game': 376,
#  'new_ford_kuga_hybrid': 377,
#  'houes taken': 378,
#  'ディズニーリゾートライン': 379,
#  'Ильдар автоподбор': 380,
#  'leaded_petrol': 381,
#  'fca': 382,
#  '700ps': 383,
#  'Carlos Ghosn': 384,
#  'Outboard motor': 385,
#  'kia seltos service cost': 386,
#  '2019 jaguar xe': 387,
#  'побить эти рекорды': 388,
#  'Verna diesel': 389,
#  'xe bánh lớn': 390,
#  'mustang india tour': 391,
#  'dive in seat': 392,
#  'surah al fatah ki fazilat': 393,
#  'porsche_la_motor_show': 394,
#  'toyota repair': 395,
#  'Arturo Magni': 396,
#  'Tata Tiago NRG': 397,
#  'видеоблог': 398,
#  'soil preparation': 399,
#  'peugeot_508_review': 400,
#  'Super Lap': 401,
#  'rolls cullinan review': 402,
#  'johnnie walker blue label': 403,
#  'Batman And Robin': 404,
#  'carwow_audi_news': 405,
#  "Machinist's workshop": 406,
#  'festival Truk': 407,
#  'ns 125 top speed': 408,
#  'black chops': 409,
#  'SPFH': 410,
#  'infiniti 2021': 411,
#  'baleno ppf costing': 412,
#  'kolli hills ride': 413,
#  'aluminium': 414,
#  'xe hay đánh giá xe': 415,
#  'pantera': 416,
#  'same tractor': 417,
#  'Danny Trejo': 418,
#  'mixing': 419,
#  'bs6 ford endeavour 2020': 420,
#  'bmw_electric_car_2021': 421,
#  'short course crash': 422,
#  'rir': 423,
#  'mercedes amg gle 53': 424,
#  'TVR Sounds': 425,
#  'Beutifull face': 426,
#  'toyota land cruiser': 427,
#  'เปลี่ยนรถเก่า': 428,
#  'Evakuasi Alat Berat': 429,
#  'Set': 430,
#  'автостраховка': 431,
#  'mest': 432,
#  'a6 audi': 433,
#  'Larini': 434,
#  'skoda scala 2019': 435,
#  'poorly_made_cars': 436,
#  'Good And Durable Second-Hand Excavator Helps To Finish This Work': 437,
#  'Excavator digging': 438,
#  '1959 Stingray Racer': 439,
#  'moto madness random acts of kindness': 440,
#  'Ваз 2106': 441,
#  'bördeln': 442,
#  'mpv': 443,
#  'استكشاف السعودية الموسم الثاني': 444,
#  'volkswagen golf5': 445,
#  'bi-turbo': 446,
#  'travel canada': 447,
#  'Coppens': 448,
#  'ola scooter': 449,
#  'carnaval': 450,
#  'Pneumatische': 451,
#  'accord': 452,
#  'Luxury': 453,
#  'jeep gladiator rubicon': 454,
#  'مواصفات رولز رويس جوست العلامة السوداء 2022': 455,
#  'hyundai creta 2021': 456,
#  'SRT 392': 457,
#  'jay leno jonathan ward': 458,
#  'Early': 459,
#  'tata nexon ev dark edition': 460,
#  'Chevy Performance': 461,
#  'Turbocharger': 462,
#  'suv comparison 2021': 463,
#  'nissan_leaf': 464,
#  '2019 genesis g70': 465,
#  'карбюратор': 466,
#  'maruti suzuki jimmy': 467,
#  'baleno hidden features': 468,
#  'vw phaeton sedan': 469,
#  'rc adventure': 470,
#  'futaba': 471,
#  'wall tap': 472,
#  'most_expensive_hatchback': 473,
#  'trekkertrekkker': 474,
#  'n240': 475,
#  'Jogjakarta Truck Festival': 476,
#  'straigh': 477,
#  'mercedes e63 amg exhaust': 478,
#  'достойные уважения': 479,
#  'mercedes concept eq': 480,
#  'meaning of name in hindi': 481,
#  'toyota_v8_review': 482,
#  'T7.270': 483,
#  'Frozen Deep Green': 484,
#  'Буйвол': 485,
#  'heatseeker': 486,
#  'Safety Driving': 487,
#  'arrma rc': 488,
#  'مازيراتي كواتروبورتي 2017': 489,
#  'e63 amg exhaust': 490,
#  'rolls royce culinan': 491,
#  'Semi Truck': 492,
#  'rough engine': 493,
#  'Lithium Iron Phosphate (Chemical Compound)': 494,
#  'fastest_audi_estate': 495,
#  'moisture inside headlight': 496,
#  'agera r': 497,
#  'baleno vs petrol race': 498,
#  'トレインビュースポット': 499,
#  'lamborghini history': 500,
#  'rc powersliding': 501,
#  'JR四国 鉄道ホビートレイン': 502,
#  'the rock': 503,
#  'subaru brx street': 504,
#  'wd-40': 505,
#  'cla 45 amg': 506,
#  'mobil toyota jadi official car': 507,
#  'вытащили двигатель': 508,
#  'Ramadan 2020': 509,
#  'How to filet': 510,
#  '2014 geneva motor show': 511,
#  'عيوب تويوتا سي اتش ار 2020': 512,
#  'best commercial trucks': 513,
#  'dodge grand caravan reliability': 514,
#  'srt4 acr': 515,
#  'old camper van': 516,
#  'shelby gt500 sound': 517,
#  'rs-3': 518,
#  'graandemodag': 519,
#  'construindo_uma_cidade': 520,
#  'straight-five engine': 521,
#  'Supercharged miata': 522,
#  '2017 metris': 523,
#  'D3 M850': 524,
#  'cadillac escalade 2021': 525,
#  'skinned knuckles': 526,
#  'Building bumblebee into a truck': 527,
#  'movie production': 528,
#  'tinkoff': 529,
#  'rx8 review': 530,
#  'Makati': 531,
#  'undercover car': 532,
#  'самые мощные': 533,
#  'tata punch drive review': 534,
#  'best_electric_sports_car': 535,
#  'the_official_motocross_videogame': 536,
#  'fiat abarth 595': 537,
#  'latest car news india': 538,
#  'van_tug_of_war': 539,
#  'WILL SMITH': 540,
#  'trick driving': 541,
#  'coolest travel gadgets': 542,
#  'rock': 543,
#  'это было последнее': 544,
#  'new scorpio launch': 545,
#  '消防博物館': 546,
#  '2019': 547,
#  'Melix': 548,
#  'permafrost': 549,
#  'mini z': 550,
#  'motocross crash': 551,
#  'Traktor Sawah': 552,
#  'stupid angry people': 553,
#  'wilhelmina polder': 554,
#  'drag week 2019': 555,
#  'lucid air specs': 556,
#  'switzerland supercarblondie': 557,
#  'Didam': 558,
#  'thar 2022 petrol': 559,
#  'автоблоги': 560,
#  'highlight reel': 561,
#  'Id4 vw': 562,
#  'worst vehicle': 563,
#  'tata prima': 564,
#  'mercedes gla 2021 india': 565,
#  '304LS': 566,
#  'corvette supercar': 567,
#  'tanner_fox_bloopers': 568,
#  '9520rx': 569,
#  'mcLaren': 570,
#  'donk magazine': 571,
#  'b3000 b4000': 572,
#  'how to replace front strut assembly': 573,
#  'टाटा इंट्रा अक्षय कुमार': 574,
#  'Catamaran (Ship Type)': 575,
#  'Zuidendijk': 576,
#  'Garage 26': 577,
#  'كريم ديب عرب جي تي': 578,
#  'honda city hybrid': 579,
#  'car dealership': 580,
#  'KitKat': 581,
#  'grand_theft_auto_5_funny_moments': 582,
#  'dssv dampers': 583,
#  'Wealthy': 584,
#  'Ford headlight installation': 585,
#  'porsche 992 911 review': 586,
#  'favourite_amg_cars': 587,
#  'le mans wheels truck': 588,
#  'ferrari roses': 589,
#  'mazdaspeed 3': 590,
#  'Surah yunis': 591,
#  'capability testing': 592,
#  'an der Knijff': 593,
#  'トミカつり': 594,
#  'nova_saveiro': 595,
#  'doing this will make your car idle better': 596,
#  'bmw 6 series gt 2021 autocar': 597,
#  'v12 biturbo': 598,
#  'ran out of gas not empty': 599,
#  'sports_car_drag': 600,
#  'BALENO vs ALTROZ vs i20 WHICH ONE TO BUY': 601,
#  'jaguar xe sv': 602,
#  'Spray Can': 603,
#  'killalltires': 604,
#  'مميزات فورد موستنج': 605,
#  'car dash camera front and rear': 606,
#  '1gz-gte': 607,
#  'Kia Seltos speaker change': 608,
#  'nexon vs tigor electric drag race': 609,
#  'Faster': 610,
#  'bmw m2': 611,
#  'е°Ҹз”°жҖҘ': 612,
#  'Ford Tractor': 613,
#  'spaceballs': 614,
#  'goldrush rally': 615,
#  'magnum 370 cvx': 616,
#  'hero bikes 2020': 617,
#  'police chase 2019': 618,
#  'como_se_beija': 619,
#  'pick': 620,
#  'audi a6 55 tfsi review': 621,
#  'charcoal canister': 622,
#  'sp2i': 623,
#  'new s class 2021': 624,
#  'COVID-19': 625,
#  'celebridades_mortas': 626,
#  'aussies': 627,
#  'cayenne 2022': 628,
#  'hack ralph': 629,
#  'new_range_rover_2021': 630,
#  'Miata': 631,
#  'prepped event': 632,
#  'bmw procar': 633,
#  'How to maintain Car in Lockdown India': 634,
#  'رام': 635,
#  'hydraulic install': 636,
#  'mini jcw r56': 637,
#  'bmw g20 review': 638,
#  'Movie Trailer': 639,
#  'Difference': 640,
#  'Детейлинг': 641,
#  'team galag snow tour': 642,
#  'VWUP': 643,
#  'supercar drag race': 644,
#  'V8 Bi-Turbo': 645,
#  'bentayga speed': 646,
#  'Kia Seltos breakdown': 647,
#  'レインボーライン': 648,
#  'ihra': 649,
#  'иап': 650,
#  'hùng lâm đánh giá xe mitsubishi triton': 651,
#  'bugatti veyron': 652,
#  'giá bán camera 360': 653,
#  'Deutz-Fahr Agromaxx Price': 654,
#  '57 chevy': 655,
#  'Post Malone': 656,
#  'animals save each other': 657,
#  'HowTo': 658,
#  'Rela Pengamen': 659,
#  'Top Spec': 660,
#  'buy engine': 661,
#  '東京メトロ': 662,
#  'surah hashr in hindi': 663,
#  'house move in': 664,
#  'tesla tires': 665,
#  'hyundai staria': 666,
#  'عيوب مرسيدس اس كلاس 2022': 667,
#  'car maker': 668,
#  'Graafmaschine': 669,
#  'giá xe audi': 670,
#  'this verse that': 671,
#  'E235': 672,
#  'tips kecantikan': 673,
#  'Unboxing a 797F': 674,
#  'おもちゃ': 675,
#  'Project car': 676,
#  'losi MT': 677,
#  'wrangler_rubicon': 678,
#  'bikers vs road rage': 679,
#  'AC3': 680,
#  '1916 Crane-Simplex': 681,
#  '25': 682,
#  'iMieV review': 683,
#  'large scale RC': 684,
#  'выгодно продать автомобиль': 685,
#  'package': 686,
#  'подготовка к родам': 687,
#  'ather 45x ota': 688,
#  'Adelfia': 689,
#  'pacific racing': 690,
#  'сток': 691,
#  'hand built porsche': 692,
#  'DJ': 693,
#  'buying a mid engine corvette': 694,
#  '2018 bmw 7 series': 695,
#  'bmw z4 m40i sound': 696,
#  'shelby gt': 697,
#  'Tata Altroz engine performance': 698,
#  'policemod': 699,
#  'india car news': 700,
#  'Tata Motors Indonesia': 701,
#  'Aquaventures': 702,
#  'Overlanding': 703,
#  'master cylinder': 704,
#  'differential science garage': 705,
#  'How To Fit Coilovers': 706,
#  'X Games Hooligan': 707,
#  'tata harrier new features': 708,
#  '6 years old': 709,
#  'Angkutan Kota': 710,
#  'most expensive model car': 711,
#  'مواصفات نيسان باترول': 712,
#  '3.6 V6 FSI': 713,
#  'formula_1_spies': 714,
#  '229mph': 715,
#  'zmax': 716,
#  'fiat spider': 717,
#  'emonds': 718,
#  'home remedy': 719,
#  'трасса': 720,
#  'Part 2 Ute Build': 721,
#  'sicky tires': 722,
#  'mercedesamg_gle_63': 723,
#  'Injecting': 724,
#  'tvs jupiter 125 launch date in india': 725,
#  '1AWWM00041': 726,
#  'Vekta 5': 727,
#  'bad suv': 728,
#  'bentley eight review': 729,
#  'fastest_amg_cars': 730,
#  'bam margera': 731,
#  'GrabCarPlus': 732,
#  'maßstab': 733,
#  'adrenaline rush': 734,
#  'HƯỚNG DẪN LÁI XE': 735,
#  'Dollar': 736,
#  'lotus evora sound': 737,
#  'leading edge machining': 738,
#  'smoke kit': 739,
#  'е38': 740,
#  'MG Hector Shine': 741,
#  'Multi axle trailer': 742,
#  'paint restoration': 743,
#  'Runge': 744,
#  'porsche 991 gt3 ipe': 745,
#  'экотэк': 746,
#  'primal rc': 747,
#  'Truck Crash': 748,
#  'hyundai creta sxo top model': 749,
#  'ostsee': 750,
#  '2019 bmw x5 india': 751,
#  'Durud e paak': 752,
#  'Kia seltos white mid mode': 753,
#  'dodge ram 2500': 754,
#  'arbeit': 755,
#  'audi rs6 c8 pov': 756,
#  'review expander': 757,
#  'Audi UR Quattro': 758,
#  'man power capsules': 759,
#  'peugeot 508 pse pov': 760,
#  'how to tell if alternator not working': 761,
#  'mclaren 600lt acceleration': 762,
#  'ответы на вопросы': 763,
#  'ralliart version-R': 764,
#  'demonstrators': 765,
#  'ghar me barkt': 766,
#  'fast cars vs bikers': 767,
#  'вилде': 768,
#  'outlander phev': 769,
#  'Замёрзший лобовик': 770,
#  'الوحيدة في العالم بالرياض': 771,
#  'livewazifa': 772,
#  'bmw i4m sound': 773,
#  'War Games': 774,
#  'Lady gaga ford lightning': 775,
#  '997 turbo acceleration': 776,
#  'volkswagen new sedan': 777,
#  'wrc_rally': 778,
#  'โตโยต้าประเทศไทย': 779,
#  'porcshe': 780,
#  'five axis': 781,
#  'new supercar blondie car tv show': 782,
#  'slavia drive review': 783,
#  'luxury lifestyle': 784,
#  'gauspak': 785,
#  'car restoration auction': 786,
#  'new_tucson_2021': 787,
#  'brake bleeding': 788,
#  'nelson engine': 789,
#  'Komatsu WB93R': 790,
#  'car polish': 791,
#  'Tractor Pulling': 792,
#  'bds motorsport': 793,
#  'найденные у животных': 794,
#  'hyundai kona n line 2021': 795,
#  'slowest': 796,
#  'good cars to buy': 797,
#  'building a trail park': 798,
#  'regera vs agera': 799,
#  'Remove Before Race': 800,
#  'kolli hills': 801,
#  'протеже': 802,
#  'suzuki s presso 2019': 803,
#  '2019 kia sp2i': 804,
#  'epic_challenge': 805,
#  'best_bmw_m2': 806,
#  'kia seltos 2022 diesel': 807,
#  'XE HAY đánh giá xe': 808,
#  'Carlender Porn': 809,
#  'Stradman Court': 810,
#  'oyster': 811,
#  'car trend': 812,
#  'bmw_i3': 813,
#  'renault kiger variants': 814,
#  'Sir dard ka wazifa': 815,
#  'c204': 816,
#  'car tiktoks': 817,
#  'путешествие': 818,
#  'Tog': 819,
#  '2022 gti review': 820,
#  'roadkill monte carlo': 821,
#  'tesla dubai': 822,
#  'estima': 823,
#  'audi sq8 2021': 824,
#  'Dumper': 825,
#  'audi rs e-tron gt review': 826,
#  'ford monster truck': 827,
#  'design engineering inc': 828,
#  's8 review': 829,
#  'Tata Tigor Ownership Experience': 830,
#  'overland': 831,
#  'cooking': 832,
#  'mahindra jeep modified': 833,
#  'failing belt tensioner': 834,
#  'best of ferrari sounds': 835,
#  'lincoln car': 836,
#  'авто с америки': 837,
#  'скафандр': 838,
#  'Heerhugowaard': 839,
#  'super_herois': 840,
#  'Pontiac': 841,
#  'ОБ ЭТОМ МНОГИЕ НЕ ДОГАДЫВАЮТСЯ': 842,
#  'chọn bmw hay mẹc': 843,
#  'suzuki bs6 2020': 844,
#  'best_supercar': 845,
#  'Mallika Dua': 846,
#  'baby powder': 847,
#  'bad turbo': 848,
#  'такое можно увидеть только в японии': 849,
#  'mercedes benz g350 diesel': 850,
#  'вы сможете': 851,
#  '1953': 852,
#  'gas additives for cars': 853,
#  'show': 854,
#  'new_vw_golf_r_review': 855,
#  'puzzle_challenge': 856,
#  'should you let your car idle before driving': 857,
#  'nico_rosberg': 858,
#  'Sumitomo HA60W': 859,
#  'chevy suburban 2021': 860,
#  'ferrari valentines gift': 861,
#  'inspiring video': 862,
#  '5 Easy Steps for Escaping the Police': 863,
#  'Hazrat Imam Ali Quotes Urdu/Hindi': 864,
#  'M Division': 865,
#  'scion tuner challenge': 866,
#  'thar accident in snow': 867,
#  'McLaren 570GT': 868,
#  'kaun banega jannati episode 68': 869,
#  'charging_an_electric_car': 870,
#  'AMG GT3': 871,
#  'xe coupe': 872,
#  'increasing cost of gold': 873,
#  'mercedes gla india 2021 review': 874,
#  '7 second': 875,
#  'minion': 876,
#  '2017 Nissan': 877,
#  'самые быстрые': 878,
#  'automotive history': 879,
#  'rs3 2022': 880,
#  'simulator': 881,
#  'eclass_review': 882,
#  'apocalypse': 883,
#  'thar offroading': 884,
#  'Casey Currie Racing': 885,
#  'g35 sedan': 886,
#  'Mr Miura': 887,
#  'car humour': 888,
#  'frame brace': 889,
#  '2018 ford mustang gt': 890,
#  'хромирование': 891,
#  'Custom RCSparks': 892,
#  'stralis': 893,
#  'neuer stromer': 894,
#  'New Bronco': 895,
#  'восстание': 896,
#  'ruf yellowbird': 897,
#  'motorbikes': 898,
#  'sl55 amg sound': 899,
#  'new_audi_concept_car': 900,
#  'xe mpv 7 chỗ giá rẻ': 901,
#  'MÀN HÌNH ANDROID': 902,
#  'nissan leaf 2019': 903,
#  'aware': 904,
#  'появления животных': 905,
#  'In Shop Repairs': 906,
#  'suzuki swift 2019': 907,
#  'сладости своими руками': 908,
#  '3гр': 909,
#  '1100': 910,
#  'cleaning windshield': 911,
#  'xe vinfast': 912,
#  'lucid vs tesla': 913,
#  'audi treser review': 914,
#  'wiring harness': 915,
#  'bumper': 916,
#  'большие колеса': 917,
#  'kia sorento 2021': 918,
#  '5.3': 919,
#  'сюрприз': 920,
#  'rally skid plate': 921,
#  'авто за 500тр': 922,
#  'kaun banega jannati episode 59': 923,
#  'syvester stalone': 924,
#  'cheapest ferrari': 925,
#  'Mercedes-AMG GT R': 926,
#  '6 speed manual': 927,
#  'Gasoline (Fuel)': 928,
#  'xe bán tải ford f 150': 929,
#  'bentley_6litre_w12': 930,
#  'geel': 931,
#  'MythConception': 932,
#  'dedication to a project': 933,
#  'фитсервис': 934,
#  'америка': 935,
#  'ระบบความปลอดภัยรถ': 936,
#  'jay leno garage restomod': 937,
#  'тайное правительство': 938,
#  'paint fade': 939,
#  'car factory': 940,
#  'jaguar_ipace': 941,
#  'tata tigor review': 942,
#  'selling_old_cars': 943,
#  'замена фрикционов': 944,
#  'turbo charger': 945,
#  'new_hatchback_review_2020': 946,
#  'turbo honda': 947,
#  'bone stock': 948,
#  'grip originals': 949,
#  'the police showed up': 950,
#  'alpha x': 951,
#  'Rauh Welt 911': 952,
#  'skoda slavia vs honda city 2022': 953,
#  'bmw 6': 954,
#  'my son': 955,
#  'lexus_lc500_review_2021': 956,
#  'group project': 957,
#  'festival of speed': 958,
#  'holland la ferrari aperta': 959,
#  'australia drifting': 960,
#  'living in a camper': 961,
#  'diesel_drag_race': 962,
#  'Sawah Lingko': 963,
#  'racechip': 964,
#  'best awd sports wagon': 965,
#  'scania torpedo': 966,
#  'جينيسيس جي 90': 967,
#  'the truth about bmw': 968,
#  'new toyota gr86 review': 969,
#  'ace hydra 14xw price': 970,
#  'illegal': 971,
#  'FC Rx7': 972,
#  'Bangkok': 973,
#  'toyota camry hybrid 2019': 974,
#  'electric scooter review': 975,
#  'swift zxi 2021': 976,
#  'dalton': 977,
#  'pink hair': 978,
#  'sls_black_series': 979,
#  'kia carens 7 seater': 980,
#  'new evoque': 981,
#  'new supercar reveal': 982,
#  'kaun banega jannati episode 131': 983,
#  'porsche cayenne 2022': 984,
#  'coupé': 985,
#  'mc_donalds_como_contruir': 986,
#  '#อาทิวราห์': 987,
#  '2020 cayenne coupe': 988,
#  'skoda slavia car': 989,
#  'humbistari kaise kare': 990,
#  'quickest_muscle_car': 991,
#  'полностью электрический': 992,
#  'p0401': 993,
#  'wagon r 2022 facelift': 994,
#  'juke': 995,
#  'Global Debut': 996,
#  'best chevy': 997,
#  'crane machine': 998,
#  'jeep wrangler 2019': 999,
#  'Ferrari 458 Spider': 1000,
#  ...}

# %%
# If I end up needing a dict that is the reverse of nodes
nodes_reversed = {}
for x,y in nodes.items():
    nodes_reversed.update({y:x})
#nodes_reversed

# %%
nodes_reversed[6444]
# Out:
# 'P0107B\nhow to'

# %%
# function to match the nodes in the edges df to the keys in the nodes dict
def match_nodes(row):
    return nodes[row['source']], nodes[row['target']]

def match_node(node):
    return nodes[node]

# %%
'''node_df=pd.DataFrame.from_dict(nodes,orient='index')
node_df.to_pickle('Data_Out/nodes.pkl')
node_df'''

# %%
dod = {}
for row in raw_df.VIDEO_TAGS:
    for subset in itertools.combinations(row, 2):
        if subset[0] not in dod:
            dod[subset[0]] = {}
        dod[subset[0]][subset[1]] = dod[subset[0]].get(subset[1], 0) + 1

# %%
# This method took 4 HOURS to get to 1,040,886 rows, approximately 1/4 complete
# Realistic to expect 16 hours for full completion!!!

'''edges = pd.DataFrame(columns=['source', 'target', 'weight'])
for word1, word_dict in dod.items():
    for word2, count in word_dict.items():
                edges = edges.append({'source': word1, 'target': word2, 'weight': count}, ignore_index=True)'''

# %%
# This method takes ~5 seconds to complete all 3,927,518 rows without the regex
## Here we are creating an in memory csv file to write to, then reading it back into a dataframe
# with the regex it takes ~45 seconds to complete all 3,927,518 rows
# ultimately the regex is necessary because there is at least one row with a newline in the word


output = StringIO()
csv_writer = writer(output)
reg1 = '\n'

for word1, word_dict in dod.items():
    for word2, count in word_dict.items():
        word1 = re.sub(reg1, '', word1)            
        word2 = re.sub(reg1, '', word2)     
        csv_writer.writerow((word1, word2, count))

output.seek(0) # we need to get back to the start of the BytesIO
edges = pd.read_csv(output, header=None, names=['source', 'target', 'weight'])
edges
# Out:
#                          source                       target  weight
# 0                  menstruation                       period       1
# 1                  menstruation             menstruation_cup       1
# 2                  menstruation                menstrual_cup       1
# 3                  menstruation               menstrual_cups       1
# 4                  menstruation  reusable_menstrual_products       1
# ...                         ...                          ...     ...
# 3927514           baleno silver       baleno top selling car       1
# 3927515           baleno silver     baleno premium hatchback       1
# 3927516    baleno 2019 facelift       baleno top selling car       1
# 3927517    baleno 2019 facelift     baleno premium hatchback       1
# 3927518  baleno top selling car     baleno premium hatchback       1
#
# [3927519 rows x 3 columns]

# %%
edges.to_pickle('Data_Out/edges.pkl')
edges.to_csv('Data_Out/edges.csv', index=False)

# %%
# delete rows with weight > 2
edges_gt_2 = edges[edges.weight > 2].copy()
edges_gt_2.dropna(inplace=True)
print(len(edges)-len(edges_gt_2), ' edges were removed')
print(len(edges_gt_2), ' edges remain')
# Out:
# 3556986  edges were removed
# 370533  edges remain

# %% [markdown]
# ## OMG its the NWB

# %%
# Creating an nwb file
with open("nodes.nwb", 'w') as f:  
    f.write("*Nodes\nid*int label*string\n")
    for key, value in nodes.items():  
        f.write('%s    "%s"\n' % (value, key))
    f.write("*UndirectedEdges\nsource*int target*int weight*int\n")
    for index, row in edges_gt_2.iterrows():
        source, target = match_nodes(row)
        f.write('%s    %s    %s\n' % (source, target, row['weight']))
