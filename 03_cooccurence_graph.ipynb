# %%
import pandas as pd
import itertools
import os
from io import StringIO
from csv import writer 
import regex as re

# %%
# Load in the data for working with. 
# This only loads the automotive channels due to time limitations in the project.
# Future progress would be to finish collecting and processing all categories, then combine them into one large file before this part.
raw_df = pd.read_pickle('Data_Out/auto_channels_data.pkl')

# %%
# Get some summary stats and a set of all nodes that we can refer to
# word_frequency_dict is for later use in making graphs
unique_words_set = set()
word_frequency_dict = {}

for row in raw_df.VIDEO_TAGS:
    for word in row:
        unique_words_set.add(word)
        word_frequency_dict[word] = word_frequency_dict.get(word, 0) + 1
del word_frequency_dict['']
unique_words_set.remove('')

print('unique_words_set: ',len(unique_words_set))
print('word_frequency_dict: ',len(word_frequency_dict))
# Out:
# unique_words_set:  125708
# word_frequency_dict:  125708

# %%
# Create a Dictionary of all nodes
# Keys are the nodes
# Values are an incrementally assigned ID number for use in our NWB file
reg1 = re.compile('[\n]') # There is at least one tag with a newline in it. 'P0107B\nhow to'
nodes = {}
Counter=1

for word in unique_words_set:
    word = re.sub(reg1, '', word)     
    nodes.update({word:Counter})
    Counter+=1
nodes
# Out:
# {'beschleunigungsmonster': 1,
#  'fastest car 2020': 2,
#  'coloridas': 3,
#  'aventador 2020': 4,
#  'bentley bentayga 2020 review': 5,
#  '2004 Toyota RAV4': 6,
#  'mach 1 mustang': 7,
#  'minecraft_surgeon': 8,
#  'jp camaro': 9,
#  'Laguna Seca': 10,
#  '488_pista_drag_race': 11,
#  'в топе': 12,
#  'GAD-Motors': 13,
#  'grip mustang eleanor gegen sls amg': 14,
#  'all_wheel_drive_bmw': 15,
#  'a-class sedan': 16,
#  'nagmani pane ka tarika': 17,
#  'smart controller': 18,
#  '2022 lexus nx': 19,
#  'best of rotary sounds': 20,
#  'siezed brake drums': 21,
#  'Toyota Camry.': 22,
#  'Maschio': 23,
#  'ls600hl': 24,
#  'audi_sedan': 25,
#  'bumpy road': 26,
#  'nitrous fire': 27,
#  'máy chạy tại nhà': 28,
#  'Akrapovic Exhaust': 29,
#  'tata mexon bs6': 30,
#  'droomrit voor het leven': 31,
#  'WOT': 32,
#  'Quester': 33,
#  'creta 2020 india accident': 34,
#  '2019 mercedes cls review': 35,
#  'Maruti Scross accident': 36,
#  'Chevrolet Duramax': 37,
#  'dino': 38,
#  'best SUV': 39,
#  'Arnold Schwarzenegger': 40,
#  'new maserati': 41,
#  'coolant reservoir tank': 42,
#  'система охлаждения': 43,
#  'motorcycle review': 44,
#  'door panel': 45,
#  'shab e qadr ramzan': 46,
#  'mg hector after creta stolen': 47,
#  'car 2016': 48,
#  'Ferrari 458 Speciale Aperta': 49,
#  'real car sounds': 50,
#  '2019 audi e-tron quattro': 51,
#  'jeep pickup': 52,
#  'crawler ted': 53,
#  'proline flat irons': 54,
#  '광고': 55,
#  '#Official': 56,
#  'review Ford F150': 57,
#  'lockedpicture': 58,
#  'auto industry news 2020': 59,
#  'Hoonigan Rob': 60,
#  'hi low': 61,
#  '2020 triumph tiger 900': 62,
#  'gt2': 63,
#  'Morgan and Son Racing': 64,
#  'gs word': 65,
#  'tata altroz 2019': 66,
#  'new lr defender': 67,
#  'owning a cop car': 68,
#  'Dirt Ramp': 69,
#  'bed lights': 70,
#  'funny_challenge': 71,
#  'dushman ke dil me rahem dalne ka wazifa': 72,
#  'supercar blondie in monaco': 73,
#  'mud paint job': 74,
#  'aston martin 2020': 75,
#  'Claeys (Organization)': 76,
#  'worn shocks and struts': 77,
#  'jeep engine swap': 78,
#  '88mm': 79,
#  'AMG EQS': 80,
#  'kbj ep 113': 81,
#  'new_model_x': 82,
#  '12 wafat ka wazifa': 83,
#  'MP-80-13T': 84,
#  'rush': 85,
#  'Hauler': 86,
#  'industry': 87,
#  'gift ideas': 88,
#  'lamborghini diablo': 89,
#  'breather': 90,
#  'carwow_saloons': 91,
#  'what is a tune up': 92,
#  'аккардеон': 93,
#  'hybrid system': 94,
#  '土産': 95,
#  '富士山ビュー特急': 96,
#  'connecting': 97,
#  'Cento Dieci': 98,
#  'Platzhirsch gegen Underdog': 99,
#  'new_2_series_2021': 100,
#  'new_hyundai_tucson_review_2021': 101,
#  'TVR S2': 102,
#  'BMX X3 2019 review': 103,
#  'door doesnt line up': 104,
#  'Stripe': 105,
#  'Halo Infinite': 106,
#  'ghost': 107,
#  '1990 nissan': 108,
#  'hyundai grand i10 nios turbo petrol review': 109,
#  'корч бмв': 110,
#  'new i20 features': 111,
#  '2021 Bronco': 112,
#  'Supra A90': 113,
#  'eboost': 114,
#  'rs e tron gt': 115,
#  'wife': 116,
#  'who bought the bugatti la voiture noire': 117,
#  'corvette vs Supra': 118,
#  'hakenlift': 119,
#  '2100 году': 120,
#  'Extravagant': 121,
#  'old yeller ii race car': 122,
#  'cars you should stay away from': 123,
#  'Mitsubishi Carisma': 124,
#  'cummins swap': 125,
#  '500e review': 126,
#  'cruiser': 127,
#  'Mk 1': 128,
#  'Cleetus mcFarland': 129,
#  'inspect rear drum brakes': 130,
#  'new bmw i3s': 131,
#  '1 star amazon products': 132,
#  'salomondrin': 133,
#  'коммерческая техника': 134,
#  'Om Telolet Om': 135,
#  'BMW G80': 136,
#  'Toyota 5 Continents Drive': 137,
#  'Porsche Targa': 138,
#  'ls2 swap': 139,
#  'Боря Павлов': 140,
#  'oficina_de_motos_brasileira': 141,
#  'Innova Crysta bs6': 142,
#  'XPANDER MT': 143,
#  'экология': 144,
#  'заброшенные автомобили со всего мира': 145,
#  '2021 jeep compass facelift': 146,
#  'анастасия заворотнюк': 147,
#  'best of lamborghini': 148,
#  'mercedes benz electric car': 149,
#  '#grabnakakalokal': 150,
#  '2019 ram 1500 price': 151,
#  'Stradman Cybertruck': 152,
#  'truck drivers in India': 153,
#  'ким': 154,
#  'have confidence while building': 155,
#  'тиму': 156,
#  'Keselamatan Diri': 157,
#  'Shelby': 158,
#  'gr_yaris_drag_race': 159,
#  'family_fun': 160,
#  'ls engine': 161,
#  'Traum': 162,
#  'knuckle busters m3': 163,
#  'vandalized': 164,
#  '765D': 165,
#  '10 car hacks': 166,
#  'set': 167,
#  'ремонта авто стяжками': 168,
#  'Gt 86 2JZ': 169,
#  'm3': 170,
#  'мир диких животных': 171,
#  'Hoonigan Moab': 172,
#  'Range Rover Evoque': 173,
#  'aero engine': 174,
#  'compass vs harrier': 175,
#  'Ferrari 599XX Evo': 176,
#  'volvo_car': 177,
#  'Chrysler Group LLC (Organization)': 178,
#  'grandparents gwagen': 179,
#  'mg hector comparison': 180,
#  'n52': 181,
#  'Mercedes E55 AMG W211': 182,
#  'klimaneutral': 183,
#  'mount_everest': 184,
#  '通勤': 185,
#  'jd power award': 186,
#  'owning a car': 187,
#  'Cheap Tires': 188,
#  'e63s': 189,
#  'leaking engine': 190,
#  '한문철': 191,
#  'kia carens 2022': 192,
#  'lamborghini urus test drive': 193,
#  'jamiroquai le mans': 194,
#  'mercedes gla 2021 india launch': 195,
#  'manhart': 196,
#  'Pott': 197,
#  'porsche taycan ev': 198,
#  'electric_car_2019': 199,
#  'tesla_dual_electric_motors': 200,
#  'triumph tiger sport 660': 201,
#  'valspar': 202,
#  'Rumptstad': 203,
#  '4x4 Suspension setup': 204,
#  'brezza cng fitted': 205,
#  'Mustang drag': 206,
#  'corner': 207,
#  '2019 toyota camry hybrid': 208,
#  'giving': 209,
#  'lego city train': 210,
#  'Mining Machinery Construction': 211,
#  'نجوم الفولكس واجن': 212,
#  'VW Golf Joker': 213,
#  '四輪駆動車': 214,
#  'motor trend hot rod': 215,
#  'Modified Live': 216,
#  'new bmw m340i': 217,
#  'grossraumbagger': 218,
#  'march': 219,
#  'tractot': 220,
#  '2018 audi q8': 221,
#  'new_bmw_electric_car': 222,
#  'Sumo World Champion': 223,
#  '#Kerala': 224,
#  'c43': 225,
#  'плохое качество': 226,
#  'winnipeg': 227,
#  'vinfast lux sa 2.0': 228,
#  'Знакомство с Тушкановой.': 229,
#  'wattagans': 230,
#  'wave độ': 231,
#  'bmw m2 lci': 232,
#  'rolls-royce silver spirit': 233,
#  'friendly bikers': 234,
#  'azure bentley': 235,
#  '#CaraMembersihkanJokMobil': 236,
#  'high lo': 237,
#  'Topgear': 238,
#  'largest RC truck ever': 239,
#  '2016 T100 Black': 240,
#  'speedo': 241,
#  '2021 audi a3 sedan review': 242,
#  'tembak reaksi': 243,
#  'sprayer': 244,
#  'moving dirt': 245,
#  'infiniti 2021': 246,
#  'How to Replace Brake Pads': 247,
#  'Toyota All New CHR': 248,
#  'ГосУслуги': 249,
#  'ford ranger raptor 2019': 250,
#  'Горы': 251,
#  'Asphalt Paving': 252,
#  'drop 2': 253,
#  'fire breathing': 254,
#  'bmw m8 competition interior': 255,
#  'panamera gts': 256,
#  'ELLEGermany': 257,
#  'ระบบเตือนการชนด้านหน้าตรง': 258,
#  'дет': 259,
#  'turboback exhaust': 260,
#  'Funniest Video KHABY LAME': 261,
#  'lamborgini sian': 262,
#  'scam': 263,
#  'construction_simulator': 264,
#  'view': 265,
#  'audi q7 acceleration': 266,
#  'DEVIL SIXTEEN': 267,
#  'axial scale truck': 268,
#  'Ford 8340': 269,
#  'narumol': 270,
#  'Potato': 271,
#  'Didam': 272,
#  'gmc or ford': 273,
#  'детеныши животных': 274,
#  '10 second': 275,
#  'gravel rally': 276,
#  'Seltos OEM Stereo Installed': 277,
#  'urus': 278,
#  'dr. dago': 279,
#  'byron dragway': 280,
#  'surah al fatah padhne ki fazilat': 281,
#  'очень': 282,
#  'Tough Truck Competition': 283,
#  'how to replace a lower radiator hose': 284,
#  'fat loss workout': 285,
#  'ps4': 286,
#  '#BetterEveryday': 287,
#  'Powertrac Euro': 288,
#  'Be your own boss': 289,
#  'volkswagon': 290,
#  'Discover More In You': 291,
#  'đánh giá xe honda sh350i 2021': 292,
#  'SIM': 293,
#  'honda civic ownership review': 294,
#  'hertz': 295,
#  'real life heroes motorcycle': 296,
#  'corolla_2018': 297,
#  'Kawasaki Z H2': 298,
#  'carwow_ttrs': 299,
#  'guide': 300,
#  'ferrari_review_2019': 301,
#  'Hyundai Safety': 302,
#  'hyundai i20 turbo dct': 303,
#  'GLS63': 304,
#  'tombos': 305,
#  'siêu xe': 306,
#  'parking deck': 307,
#  'bumer': 308,
#  'SEMA Week': 309,
#  'Бурение': 310,
#  'infiniti red sport': 311,
#  'лауд саунд': 312,
#  'audi rs6 c8 sound': 313,
#  'score': 314,
#  'edition 1': 315,
#  'science_experiment': 316,
#  'Mazda Raceway Laguna Seca (Race Track)': 317,
#  'Крокодил против бегемотов': 318,
#  'БПЛА': 319,
#  'Антон Воротников': 320,
#  'Brantas Abipraya': 321,
#  'hoonigan intimidator': 322,
#  'feel': 323,
#  'amamzing_facts': 324,
#  'hambistari karne ka tarika': 325,
#  'ford ecosport diesel manual': 326,
#  'irongav': 327,
#  'carlos lago': 328,
#  'loovered': 329,
#  'kia motor india': 330,
#  'رينو تاليسمان 2017': 331,
#  'lamborghini urus review': 332,
#  'dimitry carbonov lamborghini': 333,
#  'восьмёрка': 334,
#  'touareg 2020': 335,
#  'trump': 336,
#  'Rindu yang Terlarang Cover': 337,
#  'Volvo XC70': 338,
#  'pte': 339,
#  'limitlessfun': 340,
#  'Maruti showroom catches fire': 341,
#  'hw_honda': 342,
#  'Heavy trucking': 343,
#  'Lumi': 344,
#  'Cappenberger Straße': 345,
#  '2021 bajaj pulsar ns125': 346,
#  'Buying a c8 corvette': 347,
#  'Episode 9': 348,
#  'lastpass premium': 349,
#  'этап': 350,
#  'toyota supra review': 351,
#  'hyundai i30 n 2022': 352,
#  '英語教室': 353,
#  'GM Defense ISV': 354,
#  'жизнь на': 355,
#  'Motor World': 356,
#  'why does my steering vibrate': 357,
#  'Włosienica': 358,
#  'wölfe im schafspelz 1': 359,
#  'maserati granturismo mc stradale': 360,
#  'Adrenaline': 361,
#  '飛鳥山公園': 362,
#  'top problems dodge dakota truck': 363,
#  'bismillah shareef ka wazifa': 364,
#  'radlader': 365,
#  'Questioning Stereotypes': 366,
#  'Sallandsestraat': 367,
#  '500e': 368,
#  'MotorTrend Best Car of the Year': 369,
#  'new lexus lx': 370,
#  'new maserati review': 371,
#  'disco_sport_2019': 372,
#  'gwagon_g350': 373,
#  'audi a5 2019 review': 374,
#  '2019 ram limited review': 375,
#  'Maserati': 376,
#  'toyota lc300': 377,
#  '85': 378,
#  '2021 jeep grand cherokee': 379,
#  'Vehicle Car Tips': 380,
#  'vanessa schmitt': 381,
#  'construes': 382,
#  'uae': 383,
#  'pbi': 384,
#  'cat 777e interior': 385,
#  'Czinger': 386,
#  'schwerlast': 387,
#  'angry & cool cops': 388,
#  'Works': 389,
#  'volkswagen_arteon': 390,
#  'I just started a new YouTube Channel': 391,
#  'peugeot 308 new 2021 top speed': 392,
#  '3-serie': 393,
#  'мустанг 5': 394,
#  'ĐÁNH GIÁ XE FADIL': 395,
#  'Pebble': 396,
#  'IAMS': 397,
#  'Ian Poulter': 398,
#  'kaun banega jannati episode 99': 399,
#  'building an elefant': 400,
#  'quickest_audi_rs_2020': 401,
#  'Ferrari F12 Berlinetta': 402,
#  'lắp phụ tùng ô tô': 403,
#  'Hoonigan VHS': 404,
#  'loofklapper': 405,
#  'bmw 128ti stage': 406,
#  'ferraricollector': 407,
#  'auto legenden': 408,
#  'контакты': 409,
#  '300 SX': 410,
#  'height increase exercise': 411,
#  'Bryan Salamone': 412,
#  'подборщик': 413,
#  'expert': 414,
#  'Show': 415,
#  "Jay's favorite classics": 416,
#  'what is torque vectoring': 417,
#  'f1 driver career': 418,
#  'человек': 419,
#  'Street class NSX': 420,
#  'saveiro': 421,
#  'дергает': 422,
#  '202': 423,
#  'engine_oil': 424,
#  'gs world channel': 425,
#  'Stradman McLaren': 426,
#  'Katakan Sejujurnya': 427,
#  'door lock not working': 428,
#  'Sideways': 429,
#  'electric_car_news': 430,
#  'drinking alcohol': 431,
#  'Kang': 432,
#  'rwb stella artois': 433,
#  'kia seltos variants price': 434,
#  'glb 35 amg exhaust': 435,
#  'kill switch': 436,
#  'RX 300 2020': 437,
#  'xuv700 ppf cost': 438,
#  'đánh giá xe peugeot 3008': 439,
#  'EVAP problems': 440,
#  'audi sq5 2018': 441,
#  'смешное': 442,
#  'zuckerrübenernte': 443,
#  'toyota supra vs bmw m3': 444,
#  'mooncake festival': 445,
#  'new mercedes cars 2020': 446,
#  'bmw 330i review': 447,
#  'coolest concept cars': 448,
#  'LA car scene': 449,
#  'Gestures': 450,
#  'maruti swift 2021 lxi base model': 451,
#  'peugeot 208 signature 2019': 452,
#  'علي': 453,
#  'Pergilah Kasih Cover': 454,
#  'auto custom carpets': 455,
#  'elon musk': 456,
#  'bajaj ct 100 bs6': 457,
#  'Lowered': 458,
#  'a8l audi price': 459,
#  'Toyota Supra Mk4': 460,
#  'toyota supra mk4 fast and furious': 461,
#  'skoda slavia vs honda city comparison': 462,
#  "buying a car i've never seen before": 463,
#  'suv ev': 464,
#  'gasoline problem': 465,
#  'Friends': 466,
#  'menangkap ikan': 467,
#  'spot_hot_wheels': 468,
#  'gas powered': 469,
#  'priscia nasution': 470,
#  'ecosport 2021': 471,
#  'lesson': 472,
#  'karneval': 473,
#  'Barkat ki dua': 474,
#  'ramzan mubarak status': 475,
#  'rc4wd Evo Predator Tracks': 476,
#  'spitfire': 477,
#  'операция феррари': 478,
#  'wazifa for love marriage': 479,
#  'по всему миру': 480,
#  'audi s8 autobahn': 481,
#  'تاهو': 482,
#  'All New Pajero Sport': 483,
#  'inilne 6': 484,
#  'how to replace an alternator on a honda civic': 485,
#  'eyes': 486,
#  'vw polo gti 0-60': 487,
#  'jay lenos garage 1925 brough superior ss100': 488,
#  'drag car': 489,
#  'pulsar 125': 490,
#  'most_powerful_bmw_m_ev': 491,
#  'xuv700 20 inches alloys': 492,
#  '911 turbo stage': 493,
#  'limited edition lamborghini': 494,
#  '80 mph drifting felony': 495,
#  'Merapah Trans Jawa 4': 496,
#  'Hyundai Venue SX Sunroof 2020': 497,
#  'mercedes_electric_suv': 498,
#  'xe thể thao': 499,
#  'koenigsegg rs1': 500,
#  'buying a hyundai': 501,
#  'Best friend': 502,
#  'ремень безопасности': 503,
#  'vw tiguan review': 504,
#  'maaiarm': 505,
#  'testing fuel injecotrs': 506,
#  '1000 horsepower engine': 507,
#  '2019 toyota camry': 508,
#  'Z-Performance': 509,
#  'differential how it works': 510,
#  'Porsche 996': 511,
#  '北陸新幹線': 512,
#  'hyundai wrc': 513,
#  'chevrolet cruze': 514,
#  'апокалипсис': 515,
#  'james bond cars': 516,
#  'Snowmobile': 517,
#  '128ti': 518,
#  'Pebble Beach 2013': 519,
#  '200mph skyline': 520,
#  'Tutorial': 521,
#  'buildup': 522,
#  'eco drive mitsubishi': 523,
#  'm3_e30': 524,
#  'ignition episode 190': 525,
#  'айфон 12': 526,
#  'donkeytec': 527,
#  'Jeep Grand Cherokee (Automobile Model)': 528,
#  'nagoya': 529,
#  'thar spiti valley part 8': 530,
#  'buy a chevy': 531,
#  'muskeg': 532,
#  'Phoenix': 533,
#  'making my dad proud': 534,
#  'aspire': 535,
#  'henry ford': 536,
#  'palm beach': 537,
#  'nakai san': 538,
#  'model making': 539,
#  'agartechnik': 540,
#  'project overkill 2020': 541,
#  '2 литра': 542,
#  'Custom': 543,
#  'Dentside F-150': 544,
#  'i woke up in a new bugatti': 545,
#  "world's fanciest gear stick": 546,
#  'soundsystem': 547,
#  'limos': 548,
#  'how to change oil in a nissan': 549,
#  'fix scratches on car': 550,
#  'best utility sports wagon': 551,
#  'overivew of features': 552,
#  'природа': 553,
#  'kbj ep 133': 554,
#  'car alloy wheels stolen': 555,
#  'fun in the shop': 556,
#  'apex seals': 557,
#  'Family Adventure': 558,
#  'endeavour 2022': 559,
#  'LIVEALIVE': 560,
#  'honda engine repair': 561,
#  'еду домой': 562,
#  'лодки': 563,
#  'hyundai grand i10 2020': 564,
#  'reuniting': 565,
#  'brincando_na_piscina': 566,
#  'evving': 567,
#  'S320': 568,
#  'v12 engine': 569,
#  'cayenne s': 570,
#  'F-Sport': 571,
#  'mastermilo82': 572,
#  "here's why toyota": 573,
#  'x-trail': 574,
#  'gt-s': 575,
#  'wölfe im schafspelz': 576,
#  'xe hay đánh giá xe bmw 2020': 577,
#  'c220': 578,
#  'leh ladakh vlog': 579,
#  'Durud e paak': 580,
#  'P0358': 581,
#  'ajmer mazar sharif': 582,
#  'комфортное купе': 583,
#  'alfa romeo 166 autobahn': 584,
#  'Ralf Hack': 585,
#  'weekend seru': 586,
#  'honda amaze s': 587,
#  'битва блогеров': 588,
#  'wujudkan mimpi': 589,
#  'marty': 590,
#  'racha_proibido': 591,
#  'kaun banega jannati episode 107': 592,
#  'mod_gta_5': 593,
#  'fcev': 594,
#  'Lamborghini Huracan Evo': 595,
#  'fmatic': 596,
#  '2021 vw polo': 597,
#  'had': 598,
#  'Heffner': 599,
#  'невозможно поверить': 600,
#  'ttrs_2020': 601,
#  'Sherp ATV': 602,
#  'mahindra bolero': 603,
#  'r/t': 604,
#  '#goneanggutom': 605,
#  'range svautobiography': 606,
#  'duesenberg Walker Coupe': 607,
#  'Police Use Unlawful Tactics': 608,
#  'dzire drive review': 609,
#  "here's why ford": 610,
#  "here's why I only buy toyotas": 611,
#  'road accident funny videos': 612,
#  'Mitsubishi ECO Caravan': 613,
#  'финал': 614,
#  '2171': 615,
#  'ford mustang car': 616,
#  'Tonka': 617,
#  'boonah queensland': 618,
#  'Lamborghin Centenaroi': 619,
#  '夢クル': 620,
#  'police encounter': 621,
#  'cracked bumper': 622,
#  'renault_clio_review_2020': 623,
#  'broke': 624,
#  'slavia india': 625,
#  'xe máy điện dat bike': 626,
#  'ford mustang v8': 627,
#  'Stelzenschleppe': 628,
#  'hate tank race': 629,
#  'Toyota New': 630,
#  'f150 lightning': 631,
#  '1/18ミニカー': 632,
#  'Utah Jazz': 633,
#  'hyundai i30n exhaust': 634,
#  'around the world': 635,
#  'tuoreg': 636,
#  'прыжки в воду': 637,
#  'schoffelbalk': 638,
#  'how to make your headlights clear': 639,
#  'robotic arm': 640,
#  'trouble shoot': 641,
#  'лансер против шкоды': 642,
#  'крупная сделка': 643,
#  'ram 1500 limited': 644,
#  'bentley continental gt 2019': 645,
#  'Dump Truck loading': 646,
#  'xuv700 red color': 647,
#  't roc features': 648,
#  'voodooride s14': 649,
#  'смотать пробег': 650,
#  'head 2 head suv': 651,
#  'автомобиль из салона': 652,
#  'mustang v': 653,
#  'tata harrier xt plus features': 654,
#  'InspiringCityCar': 655,
#  'motapa dur karne ka wazifa': 656,
#  'monster truck offroading': 657,
#  'Novitec Ferrari 488 Pista': 658,
#  'GS WORLD': 659,
#  'kbj ep 8': 660,
#  'Audi RS6 plus': 661,
#  'тесты автомобилей': 662,
#  'skoda_enyaq_review_2021': 663,
#  'YouTube Collab': 664,
#  'RALLY CAR': 665,
#  'в домашних условиях': 666,
#  'французкий авто': 667,
#  'самолёты': 668,
#  'bmw z4 cũ': 669,
#  'carwow_audi_news': 670,
#  'ترحال': 671,
#  'no sleep': 672,
#  'Biggest Dog': 673,
#  'new_nissan_leaf_2020': 674,
#  'mone mudding': 675,
#  'budget track car': 676,
#  'super cars vs bikes': 677,
#  'explodes': 678,
#  'Kyosho Mini Z catches fire': 679,
#  'piaggio medley': 680,
#  'Toyota DreamOn': 681,
#  'toto wolf': 682,
#  'Mission E': 683,
#  'Transporter Tuning': 684,
#  'Würzburg': 685,
#  'filley': 686,
#  'ปันความรู้สู่สังคมไทยยั่งยืน': 687,
#  'BIỂN BÁO GIAO THÔNG': 688,
#  'jumping a vekta 5': 689,
#  'XCMG XE205C': 690,
#  '5 billion dollar car collection': 691,
#  'africa twin review': 692,
#  'dzire vxi facelift': 693,
#  '2019 grand i10 nios': 694,
#  'jeep compass': 695,
#  'How to Recharge Your Car AC': 696,
#  'lambo_huracan_sto': 697,
#  'vin inspection': 698,
#  'Texas Speed': 699,
#  '計算ドリル': 700,
#  'ochs': 701,
#  'fashionably late': 702,
#  'Range Anxiety': 703,
#  '556': 704,
#  'MG Hector plus breakdown india': 705,
#  '2020 mercedes gle 63 amg': 706,
#  'Remus': 707,
#  'parody': 708,
#  'new_fiat_500_review': 709,
#  'rear fluid change': 710,
#  'свап мотора': 711,
#  'Deman': 712,
#  'Waterproofing an RC': 713,
#  '2020 hyundai elantra review': 714,
#  'i20 ownership review': 715,
#  'Opel Mokka E': 716,
#  'Hifazat Ka Taweez': 717,
#  'Rarest': 718,
#  'how to tell if your u joints are bad': 719,
#  'gran coupe 2 series': 720,
#  'Пробег': 721,
#  'dog bite': 722,
#  'nissan magnite production specs': 723,
#  'ラッピング': 724,
#  'Imam Ali Says': 725,
#  'крайняя': 726,
#  'recirculation': 727,
#  'bimmer_drag_race': 728,
#  '£10000': 729,
#  '成田エクスプレス': 730,
#  'best tyre for car in india': 731,
#  'new_bmw_z4_2019': 732,
#  'Deutz AG (Business Operation)': 733,
#  'Ferrari Drag Race': 734,
#  'car pdi': 735,
#  'LP610-4': 736,
#  'The Torque Show': 737,
#  'lyft': 738,
#  'extreme angles': 739,
#  'D10 Dozer': 740,
#  'pontiac aztec': 741,
#  'Eco': 742,
#  'mega build': 743,
#  'lebear': 744,
#  '#1': 745,
#  'ranz niana': 746,
#  'вин номер': 747,
#  'Best Bike Tyres': 748,
#  'new_skoda_octavia_estate_review_2020': 749,
#  'cadillac 2023': 750,
#  'Laramie': 751,
#  'where did all the v8 engine cars go': 752,
#  'past': 753,
#  'the new': 754,
#  'Speed Runs': 755,
#  'Carfreitag': 756,
#  'hyundai elantra vs civic': 757,
#  'new_koenigsegg': 758,
#  '#HyundaiSUV': 759,
#  'тоёта ланд крузер': 760,
#  'bmw m550d exhaust': 761,
#  'apexer': 762,
#  'car production fails': 763,
#  'Good News': 764,
#  'Rebuilding a Ferrari': 765,
#  'el toro': 766,
#  'Opel Insignia (Automobile Model)': 767,
#  'alvida ko kya padhe': 768,
#  'Gymkhana Practice': 769,
#  'was ich mag nicht mag': 770,
#  'Cabinet': 771,
#  'liberty walk': 772,
#  'BMW M3 Competition': 773,
#  'kushaq 1.5 vs 1.0': 774,
#  'subaru cars': 775,
#  'Hyundai service': 776,
#  'skoda kushaq launch date in India': 777,
#  'powertech': 778,
#  'Tata Altroz onroad price': 779,
#  'filter': 780,
#  'kill all tires': 781,
#  'Oschersleben': 782,
#  'kbj ep 150': 783,
#  'Zorah Olivia': 784,
#  'having fun with my son': 785,
#  'kia seltos 20 inches alloys': 786,
#  'مواصفات ام جي جي تي 2022': 787,
#  'tata safari gold 2022': 788,
#  'caminhao_de_transporte': 789,
#  'wealth': 790,
#  'Nissan 300zx turbo': 791,
#  'xe hay đánh giá xe tmt': 792,
#  'Combine harvester': 793,
#  'fr 500': 794,
#  'bad auction': 795,
#  'круизер': 796,
#  'бык в деле': 797,
#  'Islam': 798,
#  'losi mini b': 799,
#  'карбон на жигули': 800,
#  'Rival': 801,
#  'power launch': 802,
#  'most_expensive_hot_hatch': 803,
#  'Yacht': 804,
#  'steve jobs car': 805,
#  'GO': 806,
#  'CV. Bangkit Makmur Abadi': 807,
#  'sleeping in a car': 808,
#  'RC4WD Wheel Loader': 809,
#  'mustang mach1 2022': 810,
#  'buying an auction car': 811,
#  'thar arun panwar delivery': 812,
#  '#ช่วงล่างSuperFlexSuspension': 813,
#  'blackwood': 814,
#  'битые тачки': 815,
#  'monster mud tires': 816,
#  'bmw 540i sound': 817,
#  'Nissan Sunny (Automobile Model)': 818,
#  'shit mechanics say': 819,
#  'volkswagen transporter': 820,
#  'hùng lâm đánh giá xe bmw': 821,
#  'smoke stacks': 822,
#  'lamborghini_electric_car': 823,
#  'McLaren 765LT': 824,
#  '2019 civic si': 825,
#  'bmw x7 m50d 0-60': 826,
#  'racing engines': 827,
#  '300000 mile fuel filter': 828,
#  'new polo': 829,
#  'shocks': 830,
#  'سعر هيونداي سنتافي جديدة': 831,
#  'Stolen': 832,
#  'air strip': 833,
#  'diagnose': 834,
#  'sport headers': 835,
#  'Milltek Audi RS6': 836,
#  'supercar blondie drifts': 837,
#  'фе': 838,
#  'dragon challenge': 839,
#  'how to get cold air in your car': 840,
#  'dbf': 841,
#  'clunking over bumps': 842,
#  'honda sh mode 2020 giá bao nhiêu': 843,
#  'policial_federal': 844,
#  'актеры гарри поттера изменились': 845,
#  'motor trend head to head': 846,
#  'mishimoto e36 bmw': 847,
#  'international raceway': 848,
#  'Hoonigan racing': 849,
#  'Decoliner': 850,
#  'upcoming new bikes': 851,
#  'auto_escola_namorada': 852,
#  'sanduiche': 853,
#  'Tiny Truck Competition': 854,
#  'prokect': 855,
#  'mokromodellbau': 856,
#  'Tony Hawk': 857,
#  'tvs jupiter': 858,
#  'headlight aiming': 859,
#  'best mining trucks': 860,
#  'porsche taycan ride': 861,
#  'campagna t rex': 862,
#  'akseer e hayat price': 863,
#  'public transportation bus': 864,
#  'BRATA': 865,
#  'pay dirt': 866,
#  'Scotto Land Rover': 867,
#  'azn': 868,
#  'милениа': 869,
#  'm340i_touring': 870,
#  'car editorial': 871,
#  'tiago cng mileage test 2022': 872,
#  'kil lall itres': 873,
#  'audi_rs3_race': 874,
#  'キャリアカー': 875,
#  'best_new_car_2022': 876,
#  '2016 nismo': 877,
#  'Idler-wheel': 878,
#  '100円': 879,
#  'v12': 880,
#  't213': 881,
#  'la_ferrari': 882,
#  'moto gp': 883,
#  'motorcycle riders': 884,
#  'updated_eclass_2020': 885,
#  'focus rs drag race': 886,
#  'treasure hunt for cash': 887,
#  'GLC 63': 888,
#  'honda civic type r sound': 889,
#  'Carbon Wheels': 890,
#  'sls_black_series': 891,
#  'Le mans': 892,
#  'supercar blondie tokyo': 893,
#  'atiqah hasiholan': 894,
#  'development': 895,
#  'mazda cx-5 2021': 896,
#  'asian games jakarta': 897,
#  'low rider s exhaust': 898,
#  'camaro zl1': 899,
#  'most': 900,
#  'pentastar v6': 901,
#  'Alinka Hardianty': 902,
#  'funny cop': 903,
#  '2021 mg hector': 904,
#  'Buying Audi R8 in Cash': 905,
#  'rimac ev': 906,
#  'Бизнес': 907,
#  'thar 2022 rescue': 908,
#  'tata tigor ev 2021 range': 909,
#  'new santro 2018': 910,
#  'porsche 911 carrera s': 911,
#  '1/14 Scale DXR2 Hydraulic Earth Dozer - RC4WD': 912,
#  'How To Replace Differential Fluids': 913,
#  'aston martin dbs top speed': 914,
#  'bikers are nice random acts of kindness': 915,
#  'ĐÁNH GIÁ HONDA CBR 650R': 916,
#  'Finally 2020 KIA Seltos Launched': 917,
#  'hot_wheels_acceleracers': 918,
#  'dirt jumps': 919,
#  'F1 speeds': 920,
#  'долгий простой': 921,
#  'running from cops': 922,
#  'miniature gold mining': 923,
#  'mega_burnout': 924,
#  'bentley arnage review': 925,
#  'rattling noise': 926,
#  'fastest_porsche_panamera': 927,
#  'track days': 928,
#  'Bentley Выпуск 2': 929,
#  'rx7 reliable': 930,
#  'virtus vs slavia': 931,
#  'unlock your adrenaline': 932,
#  'VW Group': 933,
#  'duesenberg 1931 model j': 934,
#  'コンプリート': 935,
#  'Colt Diesel Umplong': 936,
#  'giá xe volvo xc60': 937,
#  'đánh giá xe Range Rover': 938,
#  'these': 939,
#  'global time attack': 940,
#  'rat rods': 941,
#  'alpina review': 942,
#  'つばさ': 943,
#  'MG GT 2022 Price': 944,
#  'Opel Manta GSe': 945,
#  'dirty valves': 946,
#  'step by step build': 947,
#  'new_luxury_car_review': 948,
#  'toyota century review': 949,
#  'разулась': 950,
#  'handbrake slide': 951,
#  'quadricycle': 952,
#  '1st gen lightning': 953,
#  'Nexon ev electric suv': 954,
#  'Chargers': 955,
#  'Luxus': 956,
#  'Sarone': 957,
#  'Dani Sordo': 958,
#  'LCGC': 959,
#  'play_4': 960,
#  'round 3': 961,
#  'flare brake lines': 962,
#  'Example': 963,
#  'ultimate_suv': 964,
#  'lucid air 2022': 965,
#  'Trevor Harris': 966,
#  'bmw 320d restored': 967,
#  'puddling': 968,
#  'family sedan': 969,
#  'MG Hector': 970,
#  'chrix fix': 971,
#  'RoadtripParis': 972,
#  'Slovenia': 973,
#  'Murci': 974,
#  'hyundai aura': 975,
#  '1500 ps': 976,
#  'crazy carbon fiber bugatti': 977,
#  'honda city base model 2021': 978,
#  'how to jump a car': 979,
#  'билет в жизнь': 980,
#  'New Figo film': 981,
#  'How to remove a front hub actuator': 982,
#  'Rooh ka nikalna': 983,
#  'бмв м3': 984,
#  'interceptor review': 985,
#  'creta new model 2022': 986,
#  'brabus v class': 987,
#  '4 series': 988,
#  'Kei Truck': 989,
#  'giá xe moto honda 2019': 990,
#  'preload': 991,
#  'краби': 992,
#  'nissan gtr launch control': 993,
#  'swaraj stuck': 994,
#  'best_kia_2021': 995,
#  'Cy Soliman': 996,
#  'changing tires': 997,
#  'mercedes gls review': 998,
#  'камрюша': 999,
#  'onboard video': 1000,
#  ...}

# %%
# If I end up needing a dict that is the reverse of nodes
nodes_reversed = {}
for x,y in nodes.items():
    nodes_reversed.update({y:x})
#nodes_reversed

# %%
nodes_reversed[6444]
# Out:
# 'P0107B\nhow to'

# %%
# function to match the nodes in the edges df to the keys in the nodes dict
def match_nodes(row):
    return nodes[row['source']], nodes[row['target']]

def match_node(node):
    return nodes[node]

# %%
dod = {}
for row in raw_df.VIDEO_TAGS:
    for subset in itertools.combinations(row, 2):
        if subset[0] not in dod:
            dod[subset[0]] = {}
        dod[subset[0]][subset[1]] = dod[subset[0]].get(subset[1], 0) + 1

# %%
# This method took 4 HOURS to get to 1,040,886 rows, approximately 1/4 complete
# Realistic to expect 16 hours for full completion!!!
# Only left this in for posterity

'''edges = pd.DataFrame(columns=['source', 'target', 'weight'])
for word1, word_dict in dod.items():
    for word2, count in word_dict.items():
                edges = edges.append({'source': word1, 'target': word2, 'weight': count}, ignore_index=True)'''

# %%
# Here we are creating an in memory csv file to write to, then reading it back into a dataframe
# This method takes ~5 seconds to complete all 3,927,518 rows

output = StringIO()
csv_writer = writer(output)

for word1, word_dict in dod.items():
    for word2, count in word_dict.items():    
        csv_writer.writerow((word1, word2, count))

output.seek(0) # we need to get back to the start of the BytesIO
edges = pd.read_csv(output, header=None, names=['source', 'target', 'weight'])
edges
# Out:
#                          source                       target  weight
# 0                  menstruation                       period       1
# 1                  menstruation             menstruation_cup       1
# 2                  menstruation                menstrual_cup       1
# 3                  menstruation               menstrual_cups       1
# 4                  menstruation  reusable_menstrual_products       1
# ...                         ...                          ...     ...
# 3927514           baleno silver       baleno top selling car       1
# 3927515           baleno silver     baleno premium hatchback       1
# 3927516    baleno 2019 facelift       baleno top selling car       1
# 3927517    baleno 2019 facelift     baleno premium hatchback       1
# 3927518  baleno top selling car     baleno premium hatchback       1
#
# [3927519 rows x 3 columns]

# %%
edges.to_pickle('Data_Out/edges.pkl')
edges.to_csv('Data_Out/edges.csv', index=False)

# %%
# delete rows with weight <= 2
edges_gt_2 = edges[edges.weight > 2].copy()
edges_gt_2.dropna(inplace=True)
print(len(edges)-len(edges_gt_2), ' edges were removed')
print(len(edges_gt_2), ' edges remain')
# Out:
# 3556986  edges were removed
# 370533  edges remain

# %% [markdown]
# ## Export network graph to NWB format
# This is basically justa .txt file with specific formatting and the extension changed to .nwb
# The file can be opened in a text editor to get a better idea of the formatting.
# The next step with this file is to load it into Sci2 and utilize the tools there for refining and visualizing the graph.
#
# If you are on a Mac, then you cannot install Sci2, you will need to do one of the following:
# 1. Load a windows/linux VM and install Sci2
# 2. Install windows with bootcamp and install Sci2
# 3. Install Docker and run the container here:
# https://github.com/CIShell/sci2-docker-vnc

# %%
# Creating an nwb file
with open("Data_Out/graph.nwb", 'w') as f:  
    f.write("*Nodes\nid*int label*string\n")
    for key, value in nodes.items():  
        f.write('%s    "%s"\n' % (value, key))
    f.write("*UndirectedEdges\nsource*int target*int weight*int\n")
    for index, row in edges_gt_2.iterrows():
        source, target = match_nodes(row)
        f.write('%s    %s    %s\n' % (source, target, row['weight']))
